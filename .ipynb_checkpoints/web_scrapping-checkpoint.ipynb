# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
# id_inmueble = "98761768"

# %%
# url = f"https://www.idealista.com/inmueble/{id_inmueble}/"

# %%
url = "https://www.nbastuffer.com/2022-2023-nba-player-stats/"

# %%
r = requests.get(url).text

# %%
soup = bs(r)

# %%
columns_raw = soup.find_all("th")

# %%
columns = []
for column_name in columns_raw:
    columns.append(column_name.text)

# %%
for column_name in columns:

# %%
player = soup.find("td", class_ = "column-2").text
team = soup.find("td", class_ = "column-3").text

# %%
player,team,pos,age,
# Out:
# ('Bam Adebayo', 'Mia')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US" prefix="og: https://ogp.me/ns#"><head><meta charset="utf-8"/>
# <script data-cfasync="false" src="https://privacy.gatekeeperconsent.com/tcf2_stub.js"></script>
# ...
